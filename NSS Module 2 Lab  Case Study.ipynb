# %%
#Nicholas Schuhmacher 
#01/21/2026
#Module 2 Lab - Case Study: if...else and while
#takes in student name, gpa, and tests to see which list they belong on
Last_Name = input("Enter the students last name, (or ZZZ to exit program): ")
if Last_Name == "ZZZ":
    print("Ending program")

First_Name = input("Enter the students first name: ")
GPA = float(input("Enter the students GPA: "))
if GPA >= 3.5:
    print(f"{First_Name} {Last_Name} has made the Dean's List!")
elif GPA >= 3.25:
    print(f"{First_Name} {Last_Name} has made the Honor Roll!")
