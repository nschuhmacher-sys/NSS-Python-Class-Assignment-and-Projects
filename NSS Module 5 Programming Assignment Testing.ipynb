# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")
# Out:
# Everything passed

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 9
#       7 if __name__ == "__main__":
#       8     test_sum()
# ----> 9     test_sum_tuple()
#      10     print("Everything passed")
#
# Cell In[9], line 5, in test_sum_tuple()
#       4 def test_sum_tuple():
# ----> 5     assert sum((1, 2, 2)) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
#doesnt work properly in jupyter

import unittest


class TestSum(unittest.TestCase):

    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")

if __name__ == "__main_":
    unittest.main()

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"
    #the tests work good and work by running the program through unittest and making it run though multiple
    #test classes

# %%
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %%
target = __import__("my_sum.py")
sum = target.sum
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 target = __import__("my_sum.py")
#       2 sum = target.sum
#
# ModuleNotFoundError: No module named 'my_sum'

# %%
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

if __name__ == "__main_":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 import unittest
# ----> 3 from my_sum import sum
#       6 class TestSum(unittest.TestCase):
#       7     def test_list_int(self):
#
# ModuleNotFoundError: No module named 'my_sum'

# %%
from fractions import Fraction

# %%
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)

if __name__ == "__main_":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 import unittest
# ----> 3 from my_sum import sum
#       6 class TestSum(unittest.TestCase):
#       7     def test_list_int(self):
#
# ModuleNotFoundError: No module named 'my_sum'

# %%
#the tests work good and work by running the program through unittest and making it run though multiple
#test classes, we create a layered file, we get to see the properties and different methods we can use
#the code does not work properly in jupyter but it works and shows that the tests ran successfully and we 
#can see the number of tests ran and the output such as the program and equations it ran
