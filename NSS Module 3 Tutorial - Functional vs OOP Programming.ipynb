# %%
class Solution:
    def sort012(self,arr):
        arr.sort()
        return arr
        
solved_class = Solution()
arr = [0, 2, 1, 2, 0]
sorted_arr = solved_class.sort012(arr)

# %%
class Solution:    
    def binarysearch(self, arr, k):
        try:
            number = arr.index(k)
            return number
            
        except ValueError:
            return -1
